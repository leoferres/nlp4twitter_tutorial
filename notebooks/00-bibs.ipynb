# %% [markdown]
# # The Topics of the *nlp4twitter* Course

# %% [markdown]
# We will adopt a data science approach to this course in order to find which NLP techniques to study. We will "process" all articles in the [ACM DL](http://dl.acm.org/) (expanded to all records) with the word `twitter` **in the title** (we had to stop somewhere. We could have searched for `twitter` everywhere, ~2.2K results. We did, however, extend the search to the whole database, not only the ACM Full Text DB).
#
# Specifically, we ran the following query:
# ```
# Search Run Date: 2016-04-15 at 12:46:23 PM EDT
#
# Query Syntax:
# "query": { acmdlTitle:(twitter) }
#
# "filter":
# {owners.owner=GUIDE}
# ```
# which resulted in 1,307 articles matching it (as of the date above, could be more by now!).
#
# Now, ACM DL, as far as I know, doesn't allow you to download > ~1000, I did a trick: I sorted by number of citations *and* provided two ranges: the first was from 2006-2014 (998 records), and the second was from 2015-2016 (309 records), for both `.csv` and `bib` files, which I will use later.
#
# This produced the following 4 files:

# %%
acm_files = !ls data/bib/*n.*
acm_files
# Out:
# ['data/bib/acm_twitter_2006-2014_citation.bib',
#  'data/bib/acm_twitter_2006-2014_citation.csv',
#  'data/bib/acm_twitter_2015-2016_citation.bib',
#  'data/bib/acm_twitter_2015-2016_citation.csv']

# %% [markdown]
# Notice that *each file* is sorted by number of citations independently, but split on publication data. This means that the concatenation of them will not give you a complete citation-sorted file. For now, we are only be interested in the `csv` files, because they're easier to deal with in Notebooks.

# %%
import pandas as pd

# %%
acm_2006_2014 = pd.read_csv(
    "data/bib/acm_twitter_2006-2014_citation.csv")
acm_2015_2016 = pd.read_csv(
    "data/bib/acm_twitter_2015-2016_citation.csv")

# %% [markdown]
# Let's first join the two data frames:

# %%
dfs = [acm_2006_2014, acm_2015_2016]
acm = pd.concat(dfs)

# %% [markdown]
# But we don't want anything that is not a paper (e.g., we don't want books, or PhD thesis) or really care about anything but the titles (maybe), the years, and particularly, the keywords. We also get rid of nulls, which pushes us to even less records, but fine.

# %%
acm = acm[acm['type'].str.contains("article")]
acm = acm[['keywords','title','year']]
acm = acm[acm['keywords'].notnull()]
acm = acm[acm['title'].notnull()]
len(acm)
# Out:
# 905

# %% [markdown]
# The number 905 is still a gargantuan number of papers to analyze! The objective here is to get a sense of the methods used in those papers. But first, let's get rid of some of the crud. Here we split all keywords into "phrases" using "," as the splitter and convert the Pandas `Series` object into a list of lists. We then convert that list of lists into a single list whose phrases are stripped of formatting and the space character and lower-cased, and finally we get rid of duplicates:

# %%
pd.set_option('display.max_colwidth', -1)
acm.head()
# Out:
#                                                                                                                               keywords  \
# 0  Twitter, degree of separation, homophily, influential, information diffusion, online social network, pagerank, reciprocity, retweet
# 1  Twitter, earthquake, event detection, location estimation, social sensor
# 2  microblogging, social media, social network analysis, user intent
# 3  influential, pagerank, twitter
# 4  communication networks, diffusion, influence, twitter, word of mouth marketing
#
#                                                                           title  \
# 0  What is Twitter, a Social Network or a News Media?
# 1  Earthquake Shakes Twitter Users: Real-time Event Detection by Social Sensors
# 2  Why We Twitter: Understanding Microblogging Usage and Communities
# 3  TwitterRank: Finding Topic-sensitive Influential Twitterers
# 4  Everyone's an Influencer: Quantifying Influence on Twitter
#
#    year
# 0  2010
# 1  2010
# 2  2007
# 3  2010
# 4  2011

# %%
acm.to_csv('data/bib/acm.csv')

# %%
keywords = acm['keywords'].str.split(',').tolist()
keywords = [item.lower().strip() 
            for sublist in keywords for item in sublist]
keywords=set(keywords)
len(keywords)
# Out:
# 1951

# %% [markdown]
# The above process leaves "only" 1951 phrases that are unique keywords to those papers!

# %%
keywords
# Out:
# {'opinion leadership',
#  'predictive models',
#  'similarity',
#  'firm innovativeness',
#  'identity-based groups',
#  'entropy',
#  'twitter topic detection',
#  'micro-blog',
#  'spatial point pattern',
#  'german elections',
#  'semi-supervised learning',
#  'tweet',
#  'dialogic loop',
#  'web service',
#  'name disambiguation',
#  'ergm',
#  'tobacco use',
#  'audience responses',
#  'regrets',
#  'command and control',
#  'process mining',
#  'risk',
#  'media selection',
#  'internet',
#  'behavior modeling',
#  'social behavioral biometrics',
#  'document clustering',
#  'affect',
#  'news media',
#  'linguistic analysis',
#  'tagging',
#  'communication networks',
#  'election campaign',
#  'graph-based',
#  'loneliness',
#  'latent factor models',
#  'cmc',
#  'browsers',
#  'social influence',
#  'data journalism',
#  'virtual identity',
#  'unsupervised learning',
#  'quantitative evaluation',
#  'welfare',
#  'social networking potential',
#  'impact indicator',
#  'public shaming',
#  'recency ranking',
#  'protest mobilization',
#  'sentiment and emotions classification',
#  'online political participation',
#  'single-pass clustering',
#  'utility function for restrictions',
#  'children',
#  'spatio-temporal search engine',
#  'informational and social needs',
#  'metadata',
#  'mumbai terrorist attack',
#  'emotion lexicon',
#  'monitoring spread of disease',
#  'cybergis',
#  'modelling',
#  'front/back-stage',
#  'data gathering',
#  'employees',
#  'controversy',
#  'credit',
#  'banking sector',
#  'profile characteristics',
#  'social topic detection',
#  'diameter',
#  'classification',
#  'mobility',
#  'land use detection',
#  'big-five personality model',
#  'social viewing',
#  'personal health information',
#  'experimentation',
#  'open source',
#  'personal social relationships',
#  'latent attribute classification',
#  'promoting behavior',
#  'leaks',
#  'twitter corpus',
#  'dns',
#  'topical experts',
#  'conversation retrieval',
#  'ict in education',
#  'fast-greedy optimization of modularity',
#  'weak ties',
#  'activity time pattern',
#  'computational linguistics',
#  'topic classification',
#  'keyword co-occurrence pattern',
#  'agenda setting',
#  'opportunity discovery',
#  'complex contagion',
#  'information sharings',
#  'dirichlet process',
#  'twitter trend analysis',
#  'ranking mechanisms',
#  'internet measurements',
#  'geo tagging',
#  'partial differential equation',
#  'network dynamics',
#  'law enforcement',
#  'rumor spreading model',
#  'campaigning',
#  'social media monitoring',
#  'aging',
#  'principal features',
#  'civilian response',
#  'fuzzy association rule mining',
#  'scale development',
#  'text classification',
#  'place',
#  'mood diffusion',
#  'requirement-aware location recommendation',
#  'bursty keyword detection',
#  'second screen',
#  'behavior analysis',
#  'text preprocessing',
#  'classification task',
#  'u.s. congress',
#  '46--59',
#  'disease detection',
#  'assortativity',
#  'e-commerce',
#  'social bots',
#  'algorithms',
#  'digital curator',
#  'multiview clustering',
#  'correlation',
#  'differential effects',
#  'quantum cognition',
#  'multi-sided networks',
#  'blind',
#  'feedback',
#  'crisis communication',
#  'sociability',
#  'pig. apache oozie',
#  'markov random fields',
#  'innovative',
#  'mobile information retrieval',
#  'k-h networks',
#  'lexicon generation',
#  'consumer spending',
#  'three-way clustering',
#  'sns network',
#  'mood analysis',
#  'blogger',
#  'community extraction',
#  'mobile device',
#  'diseases',
#  'life activity modeling',
#  '9',
#  'bridging online social capital',
#  'workflows',
#  'singularity',
#  'tourism',
#  'twitter conversations',
#  'community question answering',
#  'real-time photo mining',
#  'global networks',
#  'feeds',
#  'opinion mining',
#  'classifier',
#  'financial',
#  'disaster response',
#  'keywords: e-commerce',
#  'twitter-specific lexicon',
#  'social news media',
#  'power-law distribution',
#  'centrality measures',
#  'visual network analysis',
#  'network',
#  'realtime',
#  'quantify',
#  'event studies',
#  'agreement technologies',
#  'sentiment mining',
#  'opportunistic networks',
#  'distributed system',
#  'social streams',
#  'rumor spreading',
#  'comparable corpora',
#  'consumer-brand relationship',
#  'scene labeling',
#  'dynamics',
#  'electronic mail',
#  'quality of services',
#  'news topic',
#  'stylometry analysis',
#  'webscience',
#  'labeled lda',
#  'arab spring',
#  'ministries',
#  'gender studies',
#  'early tsunami warning system',
#  'knapsack-constrained maximum covering problem',
#  'blogging',
#  'streaming algorithm',
#  'lda mode',
#  'ewom intentions',
#  '#tvduell',
#  'college class',
#  'multi-view hybridization',
#  'net view data',
#  'social implications of technology',
#  'service',
#  'sarcasm',
#  'engagement',
#  'cross cultural aspects',
#  'community startup',
#  'user interests',
#  'compromise',
#  'information recommendation',
#  'tie dissolution',
#  'text mining',
#  'urban',
#  'hit prediction',
#  'evocative objects',
#  'news sourcing',
#  'personality traits',
#  'feature buzz summary',
#  'query expansion',
#  'distance',
#  'data collection',
#  'inferring social ties',
#  'stopwords',
#  'crisis informatics',
#  'recency',
#  'video recommendation',
#  'willingness',
#  'boston',
#  'popular users',
#  'sampling from experts',
#  'mixed-methods',
#  'fact triplet extraction',
#  'business intelligence',
#  'consumer engagement',
#  'recommender',
#  'user experience',
#  'collaborative communities',
#  'social media marketing',
#  'computer-mediated communication',
#  'sentiment classification',
#  'social network discovery',
#  'online community',
#  'graph-based classification',
#  'data sampling',
#  'degree distribution',
#  'complex networks',
#  'social network sites',
#  'click-through prediction',
#  'information need',
#  'group dynamics',
#  'support vectors machine',
#  'twitter user search',
#  'behavioral analysis',
#  'reputation',
#  'enterprise',
#  'voting',
#  'irony detection',
#  'semantic elements extraction',
#  'social capital',
#  'need for cognition',
#  'uec-food100',
#  'social media brand',
#  'opinion leaders',
#  'compromised accounts',
#  'spamdexing',
#  'cross-platform',
#  'semantics',
#  'twitter stream analysis',
#  'localized events',
#  'personality',
#  'bibliometrics',
#  'graph theory',
#  'microblogging services',
#  'social cascading',
#  'statistical machine translation',
#  'violent groups supporters',
#  'topic models',
#  'amazon',
#  '<b>t</b>witter',
#  'digital methods',
#  'volatility',
#  'wisdom of crowds',
#  'collaborative filtering',
#  '19',
#  'seekers of topical information',
#  'disaster',
#  'nonprofit organizations',
#  'zookeeper',
#  'analytics',
#  'swine flu',
#  'geographic clustering',
#  'iran',
#  'online social networking',
#  'co2',
#  'language model',
#  'wikipedia',
#  'semantic kernel representation',
#  'location-based microblogs',
#  'discovery',
#  'newsgathering',
#  'trend detection',
#  'topic association',
#  'social tagging',
#  'recency modeling',
#  'censorship',
#  'news',
#  'linkage',
#  'library list',
#  'social activism',
#  'social media credibility',
#  'social network security',
#  'semantic role labelling',
#  'ili',
#  'conversation analysis',
#  'iemocap',
#  'quantitative-network analysis',
#  'web impact analysis',
#  'parallel coordinates visualization',
#  'reply prediction',
#  'communities of practice',
#  'photo tweet',
#  'trust',
#  'social role theory',
#  'drug trends',
#  'conference',
#  'mobilization',
#  'twitter context tree',
#  'social media search',
#  'exponential random graph model',
#  'collective user behaviour',
#  '94a02',
#  'regression on tweets',
#  'drugs',
#  'identity management',
#  'content based recommendation',
#  'crowd sourcing',
#  'semeval',
#  'real-world events',
#  'social network service',
#  'health communication',
#  'bayesian network',
#  'event timespan computation',
#  'retweet probability',
#  'retweet network',
#  'malicious users',
#  'aic',
#  'narcissism',
#  'reply behavior',
#  'tourism behavior',
#  'reproducibility',
#  'twitter event detection',
#  'lexical normalization',
#  'political marketing',
#  'keyword focus',
#  'natural disasters',
#  'friend recommendation',
#  'relationship building',
#  'random sampling',
#  'online marketing communication',
#  'attribute learning',
#  'follower markets',
#  'online advertising',
#  'workplace communication',
#  'expertise finding',
#  'apache hadoop',
#  'local expert',
#  'and visual analytics',
#  'genre analysis',
#  'routing algorithm',
#  'political orientation',
#  'public timeline',
#  'location-based social network sites',
#  'passive consumption',
#  '76m27 visualization algorithms',
#  'mutual information',
#  'behavioral-based',
#  'persuasive systems design',
#  'pandora',
#  'overlapping community',
#  'quantitative',
#  'electronic government',
#  'ads targeting',
#  'discussion groups',
#  'unfollow',
#  'micro-blogs',
#  'speech codes theory',
#  'computational analysis',
#  'urban computing',
#  'visualization',
#  'crisis coordination',
#  'complex interactive systems',
#  'time zone',
#  'reuse',
#  'breaks',
#  'social spam profile (ssp)',
#  'performance',
#  'us congress',
#  'comparison orientation',
#  'social networking',
#  'information discovery',
#  'citizen engagement',
#  'feature interpolation',
#  'dengue',
#  'security',
#  'sports video',
#  'terminology clustering',
#  'community awareness',
#  'online discussion',
#  'late fusion',
#  'real-time systems',
#  'structured event mining',
#  'epidemic intelligence',
#  'big data algorithm',
#  'fireme!',
#  'profile attributes',
#  'information amplification',
#  'characteristic co-occurrence word',
#  'interestingness',
#  'infectious disease',
#  'geocoding',
#  'political discourse',
#  'participation',
#  'social attention',
#  'pls',
#  'personality traits prediction',
#  'marketing',
#  'content dissemination',
#  'information cues',
#  'ranking strategy',
#  'remote diagnosis',
#  'open government initiative',
#  'constructivism',
#  'language-game and natural language processing',
#  'soa',
#  'attribute-value extraction',
#  'e-business',
#  'tie breaks',
#  'som',
#  'parsing',
#  'information use',
#  'political talk',
#  'cascades',
#  'biological system modeling',
#  'deception',
#  'legislation',
#  'ranking svm',
#  'peer recommendation',
#  'stock price',
#  'political preference',
#  'pos sequence',
#  'south korea',
#  'twitter lists',
#  'news articles',
#  'word of mouth marketing',
#  'event mining',
#  'information-flow',
#  'field experiments',
#  'continuance',
#  'isis',
#  'electronic governance',
#  'human factors',
#  'social support',
#  'propaganda',
#  'suspiciousness',
#  'higher education',
#  'liberal',
#  'expertise',
#  'semisupervised learning',
#  'locality',
#  'monitoring social media',
#  'machine intelligence',
#  'topic detection',
#  'system-generated cues',
#  'computer science',
#  'online relationship',
#  'social media analytics',
#  'islamic extremism',
#  'cognitive informatics',
#  'multi-label classification',
#  'topic detection and tracking',
#  'predicting engagement',
#  'retweet bahavior prediction',
#  'disaster management agencies',
#  'early warning',
#  'apology',
#  'twitter stream',
#  'cloud computing',
#  'recommender system',
#  "patient's language learning",
#  'early detection',
#  'time',
#  'twitter hyperlink recommendation',
#  'label propagation model',
#  'complex network',
#  'user interest',
#  'real-time',
#  'large-scale machine learning',
#  'psychological states',
#  'emotion recognition',
#  'spam-farms',
#  'web 2.0',
#  'retention',
#  'motion pictures',
#  'suicide',
#  'microblogging',
#  'recommendation systems',
#  'jvm',
#  'discovering',
#  'na&#239;ve bayes',
#  'google trends',
#  'multirelation',
#  'twitter ecosystem',
#  'anonymous',
#  'news recommendations',
#  'scholarly communication',
#  'degree of separation',
#  'emotion identification',
#  'information overload',
#  'natural calamities',
#  'real-time recommendation',
#  'multi-agent',
#  'opinion switch',
#  'prediction',
#  'sentiment lexicon',
#  'concept learning',
#  'forensics',
#  'virtual communities',
#  'micro-blog mining',
#  'expertise judgment',
#  'spatial diffusion',
#  'online behavior',
#  'uniform',
#  'topical proximity',
#  'crowd behavior',
#  'event extraction',
#  'replicator dynamics',
#  'micro cluster',
#  'information seeking',
#  'transportation',
#  'stream data management',
#  'groups',
#  'earthquake',
#  'software development',
#  'scientometrics and scholarly communication',
#  'cursing.',
#  'named entities',
#  'bot',
#  'attention simulator',
#  'context-aware recommendation',
#  'inference',
#  'online social networks',
#  'risk communication',
#  'feature engineering',
#  'n-grams',
#  'jensen-shannon divergence',
#  'trend identification',
#  'crawlers',
#  'subjectivity',
#  'network learning',
#  'crisis',
#  'location inference',
#  'web-based interaction',
#  'regional aspects',
#  'hashtag prediction',
#  'trend prediction',
#  'predictions',
#  'collaborator recommendation',
#  'crowdsourcing',
#  'originating behavior',
#  'dbpedia',
#  'temporal text mining',
#  'memory',
#  'gender difference',
#  'retweeter',
#  'web of things',
#  'data management',
#  'public belief analysis',
#  'india',
#  'yik yak',
#  'social web',
#  'sentiment dimensions',
#  'categorical attributes',
#  'semantic patterns',
#  'machine learning',
#  'malicious campaigns',
#  'user profiling',
#  'who is who',
#  'information behavior',
#  'cluster analysis',
#  'usability',
#  'feature relevance decay',
#  'lobbying',
#  'political communication',
#  'incremental',
#  'corpus creation',
#  'persuasive software features',
#  'monitoring',
#  'twitter geolocation',
#  'discussion',
#  'community comparison',
#  'informedness',
#  'social semantic web',
#  'social psychology',
#  'scientific communities',
#  'personality mining',
#  'live-tweeting',
#  'source and sink mechanism',
#  'social media mining',
#  'membership',
#  'sns',
#  'sociolinguistics',
#  'annotation',
#  'spatial signature',
#  'bonding online social capital',
#  'social research',
#  'cascade',
#  'selective exposure',
#  'affective interactional prototype development',
#  'twitter search',
#  'is continuance',
#  'picarro',
#  'you tube',
#  'data analyzing',
#  'web mashup',
#  'real-world activity',
#  'police',
#  'latent user models',
#  'weak retweet',
#  'attraction',
#  'social broadcasting',
#  'tweets',
#  'survey research',
#  'epidemiological modeling',
#  'language models',
#  'insomnia',
#  'sybils',
#  'green movement',
#  'information dissemination',
#  'event data',
#  'super bowl 2012',
#  'burst detection',
#  'logistic regression',
#  'content virality',
#  'bridging',
#  'mashup technology',
#  'feature extraction',
#  'stream data processing systems',
#  'salience theory',
#  'abandoners',
#  'eu',
#  'computational and artificial intelligence',
#  'web image mining',
#  'disasters',
#  'electoral prediction',
#  't-closeness',
#  'small sample datasets',
#  'multilingualism',
#  'memory allocation',
#  'level of danger',
#  'hci',
#  'conditional random fields',
#  'interactivity',
#  'twitter user mood prediction',
#  'energy function',
#  'theory',
#  'decentralized network architectures',
#  'language usage',
#  'user engagement',
#  '#hashtag',
#  'gis',
#  'micro blogs',
#  'bayesian model',
#  'training',
#  'thumb-based ranking',
#  'language',
#  'curation',
#  'h1n1',
#  'reference services',
#  'programming',
#  'skewnness',
#  'social network forensic analysis',
#  'twitter streaming data',
#  'emotion',
#  'urban life monitoring',
#  'machine learning classifier',
#  'spatio-temporal analysis',
#  'public participation',
#  'event message identification',
#  'epidemics detection',
#  'vote',
#  'exchange rate modeling',
#  'feature-based opinion summarization',
#  'humor recognition',
#  'matrix factorization',
#  'returns',
#  'online social network',
#  'metwork informal language',
#  'climate change',
#  'collusionrank',
#  'public health informatics',
#  'mining',
#  'nokia internet pulse',
#  'snowball sampling',
#  'periodic time series',
#  'two-step flow of communication',
#  'oai-pmh',
#  'geo-tagged',
#  '11',
#  '10',
#  'television',
#  '17',
#  'emotion intelligence',
#  '18',
#  'location based social networks',
#  'networks of diffusion',
#  'web n-gram',
#  'multilingual communication',
#  'support vector',
#  'selection bias',
#  'user classification',
#  'communication patterns',
#  'topics',
#  'social medium',
#  'news story',
#  'pubmed',
#  'named entity recognition',
#  'pervasive computing',
#  'knowledge base',
#  'topic analysis',
#  'short text message',
#  'hollywood movies',
#  'mobile apps',
#  'information rights',
#  'q&a',
#  'user behavior',
#  'risk choice strategy',
#  'social informatics',
#  'digital forensics',
#  'time-aware',
#  'personalized ranking',
#  'hdp-hmm',
#  'pagerank',
#  'user profile construction',
#  'aspect-based sentiment analysis',
#  'demographic analysis',
#  'global health and well-being',
#  'nlp',
#  'taxonomy inference',
#  'lexicon',
#  'spatial clustering',
#  'message diffusion',
#  'social features',
#  'geography',
#  '311 civil complaints',
#  'ensembles',
#  'clustering coefficient',
#  'epidemics distribution',
#  'awareness',
#  'pattern recognition systems and applications',
#  'semantic annotation',
#  'ranking',
#  'locally adaptive kernel',
#  'identity recognition',
#  'event discovery',
#  'mentions/replies',
#  'latin america',
#  'event type prediction',
#  'bayes model',
#  'social networking site design and use',
#  'floods',
#  'text stream',
#  'topic derivation',
#  'email',
#  'bayesian theorem',
#  'social media stream',
#  'twitter bio',
#  'psychopathy',
#  'campaign detection',
#  'security informatics',
#  'dempster-shafer theory',
#  'text-tv',
#  'social movement network analysis',
#  'personality recognition',
#  'k-anonymity',
#  'contentious politics',
#  'mass assignment',
#  'weibo',
#  'technology-mediated social participation',
#  'digital evidence',
#  'daily deal service',
#  'forecast',
#  'query suggestion',
#  'verification',
#  'online reputation management',
#  'social network analysis',
#  'border intelligence',
#  'advertisability',
#  'customer relationship',
#  '20',
#  'motivations',
#  'latent variable inference',
#  'data visualization',
#  'health information visualization',
#  'probabilistic model',
#  'e-government',
#  'hashtag recommendation',
#  'pakistan',
#  'forecasting',
#  'filtering',
#  'cancer',
#  'stream analysis',
#  'sampling',
#  "spammers' linking strategies",
#  'digital repository integration',
#  'learning',
#  'data mining',
#  'twitter analytics',
#  'document categorization',
#  'co-organization',
#  'content curation',
#  'terrorism communication',
#  'feature detection &#38; tracking',
#  'accessibility',
#  'location-time constrained topic',
#  'microblogging data',
#  'affective lexicon',
#  'election prediction',
#  'casa',
#  'hdp',
#  'visual knowledge discovery',
#  'tweet stories',
#  'technology adoption',
#  'social hierarchy',
#  'social media data mining',
#  'conferences',
#  'dynamic temporal map',
#  'data capture',
#  'social event detection',
#  'restricted network growth',
#  'discovery analytics',
#  'technology',
#  'microposts',
#  'fuzzy formal concept analysis',
#  'media',
#  'social network distance',
#  'surveillance',
#  'url redirection',
#  'followers',
#  'relationship marketing',
#  'events',
#  'oil',
#  'inverted indexing',
#  'density ratio estimation',
#  'running',
#  'crowd knowledge',
#  'social comparison',
#  'coping strategies',
#  'data-mining',
#  'trending topics',
#  'aging theory',
#  'agent-based social simulation',
#  'nosql',
#  'food photo recognition',
#  'bursty words',
#  'epidemics spread',
#  'collaborative personalized search',
#  'social and behavioral sciences',
#  'user issues',
#  'duplicate detection',
#  'twitter entities',
#  'blog',
#  '4',
#  'micro-celebrities',
#  'latent dirichlet allocation',
#  'information visualization',
#  'traffic',
#  'cyber security',
#  'micro-blogging',
#  'computer mediated communication',
#  'pharmacovigilance',
#  'visual impairments',
#  'mining online communities',
#  'behavioral patterns',
#  'opinion strength',
#  'topic detection on short-message',
#  'millennials',
#  'ehealth',
#  'disciplinary differences',
#  'class balancing',
#  'public relations',
#  'competition',
#  'information retrieval',
#  'topic inference',
#  'passive social media use',
#  'mental health',
#  'mood',
#  'user sentiment analysis',
#  'memories',
#  'online public forum',
#  'conservative',
#  'work-related twitter use',
#  'viral content',
#  'business',
#  'data summarization',
#  'ads selection',
#  'online social network (osn)',
#  'terrorism informatics',
#  'ontology',
#  'collaborative learning',
#  'word clouds',
#  'informal communication',
#  'two-step flow',
#  'feature selection',
#  'socialbots',
#  'account abuse',
#  'influential community detection',
#  'search interfaces',
#  'communication',
#  'image',
#  'user relations',
#  'interest analysis',
#  'homeless',
#  'information balance',
#  'emotion sensing',
#  'scientific influence-passivity-score (sip-score)',
#  'argumentation',
#  'environmental organizations',
#  'behavioral modeling',
#  'semantic enrichment',
#  'communication design',
#  'hazards',
#  'expertise score',
#  'mediated disclosure',
#  'digital library',
#  'gubernatorial election',
#  'binary classification',
#  'multi-agent system',
#  'online social media',
#  'apache hbase',
#  'early warning systems',
#  'twitter resources',
#  'social media communication',
#  'geohashviz',
#  'reference groups',
#  'datasets',
#  'truncated data',
#  'online harassment',
#  'andy carvin',
#  'application for social network',
#  'word of mouth',
#  'google scholar',
#  'academic conferences',
#  'online social networks (osns)',
#  'youtube',
#  'measurement',
#  'mobile computing',
#  'suspicious url',
#  'politics',
#  'occupy wall street',
#  'tweet score',
#  'geographic information retrieval',
#  'fake user accounts',
#  'credibility',
#  'hybrid',
#  'suspicious profiles',
#  'information storage and retrieval',
#  'literature-based discovery',
#  'congress',
#  'symbolic aggregate approximation',
#  'interactions of tweets',
#  'polarity classification',
#  'fcb-grid model',
#  'link decay',
#  'non-malicious users',
#  'tweet categories',
#  'user influence',
#  'stochastic gradient descent',
#  'websites',
#  'real time rank',
#  'implicit crowdsourcing',
#  'cross-media analysis',
#  'influenza',
#  'human-computer interaction',
#  'electronic commerce',
#  'influence analysis',
#  'realtime analysis',
#  'short-text classification',
#  'network evolution',
#  'rumor detection',
#  'followees',
#  'polarity',
#  'online recommendation',
#  'community dynamics',
#  ...}
